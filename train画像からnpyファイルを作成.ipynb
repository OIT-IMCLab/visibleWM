# %%
import numpy as np

from urllib import request
from PIL import Image

import matplotlib.pyplot as plt
import os
import copy
import cv2
import numpy as np
import torch
from torchvision import models
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
IMG_SIZE = 32
num_classes = 1000
x = []
y = []
x_train = []  # 学習用画像データ
y_train = []  # 学習用ラベル情報
training_data = []
test_data = []
datadir = 'imagenet12\\train'#train画像のパス

# %%
###トレーニング画像読み込み
for num in range(1000):
    if num < 9:
        num2 ='000'
    elif 9 <= num and num <99:
        num2 ='00'
    elif 99 <= num and num < 999:
        num2 ='0'
    else:
        num2=''
    num_f=num2+str(num+1)
    path = os.path.join(datadir, num_f)
    print(path)
    count=0
    for image_name in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path, image_name))  # 画像読み込み
            img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
            img_resize_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            training_data.append([img_resize_array,num])  # 画像データ、ラベル情報を追加 
            count=count+1
        except Exception as e: 
            pass
            
            
for feature, label in training_data:
    x_train.append(feature)
    y_train.append(label)

# numpy配列に変換
x_train = np.array(x_train)
y_train = np.array(y_train)

print('trainshape:',x_train.shape, y_train.shape)

np.save('x_train.npy',x_train)
np.save('y_train.npy',y_train)

print('collect')
# Out:
# imagenet12\train\0001
# imagenet12\train\0002
# imagenet12\train\0003
# imagenet12\train\0004
# imagenet12\train\0005
# imagenet12\train\0006
# imagenet12\train\0007
# imagenet12\train\0008
# imagenet12\train\0009
# imagenet12\train\0010
# imagenet12\train\0011
# imagenet12\train\0012
# imagenet12\train\0013
# imagenet12\train\0014
# imagenet12\train\0015
# imagenet12\train\0016
# imagenet12\train\0017
# imagenet12\train\0018
# imagenet12\train\0019
# imagenet12\train\0020
# imagenet12\train\0021
# imagenet12\train\0022
# imagenet12\train\0023
# imagenet12\train\0024
# imagenet12\train\0025
# imagenet12\train\0026
# imagenet12\train\0027
# imagenet12\train\0028
# imagenet12\train\0029
# imagenet12\train\0030
# imagenet12\train\0031
# imagenet12\train\0032
# imagenet12\train\0033
# imagenet12\train\0034
# imagenet12\train\0035
# imagenet12\train\0036
# imagenet12\train\0037
# imagenet12\train\0038
# imagenet12\train\0039
# imagenet12\train\0040
# imagenet12\train\0041
# ...
